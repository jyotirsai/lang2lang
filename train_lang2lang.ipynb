# %%
# %%capture
# !pip install datasets
# !pip install tokenizers
# !pip install mlflow

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/jyotirsai/lang2lang.git

# %%
# %cd /content/drive/MyDrive/Notebooks/lang2lang

# %%
# !mkdir -p /content/drive/MyDrive/Notebooks/lang2lang/weights
# !mkdir -p /content/drive/MyDrive/Notebooks/lang2lang/vocab

# %%
# %%capture
# %cd /content/lang2lang

# %%
from config import get_config

# %%
config = get_config()
config

# %%
config['model_folder'] = '..//drive/MyDrive/Notebooks/lang2lang/weights'
config['tokenizer_file'] = '..//drive/MyDrive/Notebooks/lang2lang/vocab/tokenizer_{0}.json'

# %%
from train import train

# %%
train(config)
